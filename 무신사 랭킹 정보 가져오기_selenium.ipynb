# %%
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# %%
path = 'C:\\Users\\BLUE\\Desktop\\Selenium\\chromedriver'
driver = webdriver.Chrome(path)

# %%
driver.get('https://store.musinsa.com/app/')

# %%
elem = driver.find_element_by_css_selector('#default_top > div.main-wrapper.wrapper > div.gnb.wrapper.clearfix > ul > li.hovering.gnb-ranking-list > a')
elem.click()

# %%
#이미지링크 가져오는 코드
elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child(1) > div.li_inner > div.list_img > a > img').get_attribute('data-original')
print(elem)
# Out:
# https://image.msscdn.net/images/goods_img/20200806/1540376/1540376_3_125.jpg

# %%
from selenium.webdriver.common.keys import Keys

for i in range(1,91):
    print(i,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(4)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+90,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(5)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+180,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
# Out:
# 1 위
# 브랜드: 아디다스
# 제품: 아디브레이크 팬츠 - 블랙:화이트 / GJ6580
# 가격: 89,000원
# 69,900원
# 이미지 https://image.msscdn.net/images/goods_img/20200806/1539028/1539028_1_125.jpg
#
# 2 위
# 브랜드: 라퍼지스토어
# 제품: 버핑레더 미니멀 포켓 블루종_Black
# 가격: 94,000원
# 74,900원
# 이미지 https://image.msscdn.net/images/goods_img/20200806/1540376/1540376_3_125.jpg
#
# 3 위
# 브랜드: 모디파이드
# 제품: [오늘만이가격]M1665 글렌체크 싱글 블레이져
# 가격: 135,000원
# 88,000원
# 이미지 https://image.msscdn.net/images/goods_img/20180920/864404/864404_1_125.jpg
#
# 4 위
# 브랜드: 알파 인더스트리
# 제품: 2 / 8 배송 MA-1 레귤러 Sage green
# 가격: 225,000원
# 209,300원
# 이미지 https://image.msscdn.net/images/goods_img/20160912/411214/411214_4_125.jpg
#
# 5 위
# 브랜드: 페이탈리즘
# 제품: #0214 Moderation indigo straight fit
# 가격: 83,000원
# 49,000원
# 이미지 https://image.msscdn.net/images/goods_img/20190919/1159065/1159065_2_125.jpg
#
# 6 위
# 브랜드: 파르티멘토
# 제품: 3M 신슐레이트 M-51 피시테일 코트 패딩 카키
# 가격: 155,000원
# 99,900원
# 이미지 https://image.msscdn.net/images/goods_img/20191028/1204448/1204448_2_125.jpg
#
# 7 위
# 브랜드: 클락스
# ...

# %%
#완성본
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup
import time 

path = 'C:\\Users\\BLUE\\Desktop\\DataScience\\Selenium\\chromedriver'
driver = webdriver.Chrome(path)

driver.get('https://store.musinsa.com/app/')

elem = driver.find_element_by_css_selector('#default_top > div.main-wrapper.wrapper > div.gnb.wrapper.clearfix > ul > li.hovering.gnb-ranking-list > a')
elem.click()

from selenium.webdriver.common.keys import Keys

for i in range(1,91):
    print(i,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(4)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+90,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(5)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+180,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
    
elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(6)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+270,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
    
elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(7)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+360,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(8)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+450,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
    
elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(9)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+540,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(10)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+630,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(11)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+720,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
    
elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(12)')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+810,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')

elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a.fa.fa-angle-right.paging-btn.btn.next')
elem.send_keys(Keys.ENTER)

for i in range(1,91):
    print(i+900,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
    
elem = driver.find_element_by_css_selector('#goodsRankForm > div.right_contents.hover_box > div.boxed-list-wrapper.rank-shop > div > div.pagination-box.box > div > div > a:nth-child(4)')
elem.send_keys(Keys.ENTER)
          
for i in range(1,91):
    print(i+990,'위')
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.item_title > a'.format(i))
    print('브랜드:',elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.list_info > a'.format(i))
    print('제품:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.article_info > p.price'.format(i))
    print('가격:', elem.text)
    elem = driver.find_element_by_css_selector('#goodsRankList > li:nth-child({}) > div.li_inner > div.list_img > a > img'.format(i)).get_attribute('data-original')
    print('이미지', elem)
    print('')
# Out:
# 1 위
# 브랜드: 컨버스
# 제품: 척 70 클래식 블랙 162058C
# 가격: 89,000원
# 80,100원
# 이미지 https://image.msscdn.net/images/goods_img/20180703/810034/810034_2_125.jpg
#
# 2 위
# 브랜드: 슈펜
# 제품: [핏더사이즈X슈펜] Seku-shi(세쿠시) 첼시 부읏츠 BYTM20W12
# 가격: 139,000원
# 111,200원
# 이미지 https://image.msscdn.net/images/goods_img/20200828/1568047/1568047_5_125.jpg
#
# 3 위
# 브랜드: 알파 인더스트리
# 제품: MA-1 레귤러 Black
# 가격: 225,000원
# 209,300원
# 이미지 https://image.msscdn.net/images/goods_img/20160912/411209/411209_1_125.jpg
#
# 4 위
# 브랜드: 무신사 스탠다드
# 제품: [유아인 착장상품]테이퍼드 히든 밴딩 크롭 슬랙스 [블랙]
# 가격: 32,900원
# 이미지 https://image.msscdn.net/images/goods_img/20190910/1149328/1149328_5_125.jpg
#
# 5 위
# 브랜드: 컨버스
# 제품: [TV CF상품]척 70 클래식 블랙 162050C
# 가격: 95,000원
# 85,500원
# 이미지 https://image.msscdn.net/images/goods_img/20180703/810033/810033_2_125.jpg
#
# 6 위
# 브랜드: 제로
# 제품: Classic Sweat Pants [Grey]
# 가격: 39,000원
# 이미지 https://image.msscdn.net/images/goods_img/20160902/404949/404949_1_125.jpg
#
# 7 위
# 브랜드: 아디다스
# 제품: BW 독일군 스니커즈 - 화이트 / BZ0579
# ...
