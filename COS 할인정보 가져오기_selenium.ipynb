# %%
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from selenium.webdriver.common.keys import Keys

# %%
path = 'C:\\Users\\BLUE\\Desktop\\DataScience\\Selenium\\chromedriver'
driver = webdriver.Chrome(path)

# %%
driver.get('https://www.cosstores.com/en_de/men/archive-sale.html')
time.sleep(2)

# %%
elem = driver.find_element_by_css_selector('#main-content > div > div.genericpagepar.parsys > div.productlisting.parbase.section > div.u-cols-lg-24-24.u-cols-md-12-12.u-cols-sm-12-12.u-row.u-full-width > div > div > div.o-product-sort > div > div > div > div > div > button.a-button-nostyle.placeholder > span:nth-child(1)')
elem.click()
time.sleep(1)

elem = driver.find_element_by_css_selector('#brand3 > span')
elem.click()
time.sleep(1)

# %%
#하나하나 스크롤 내리는 코드
data = [i for i in range(1,50000) if i %500 ==0]
import datetime
def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    for x in data:
        driver.execute_script("window.scrollTo(0, {})".format((x)))
        time.sleep(2)
        if datetime.datetime.now() > end:
            break
            
doScrollDown(100)

# %%
SCROLL_PAUSE_SEC = 3

# 스크롤 높이 가져옴
last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # 끝까지 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 1초 대기
    time.sleep(SCROLL_PAUSE_SEC)

    # 스크롤 다운 후 스크롤 높이 다시 가져옴
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
product_list = list()
elem = driver.find_elements_by_class_name('product-title')
for i in elem:
    product_list.append(i.text)
print(product_list)
len(product_list)
# Out:
# ['ROUND-NECK T-SHIRT', 'RECYCLED POLYESTER 3-PANEL BUCKET HAT', 'MESH BASEBALL CAP', 'LEATHER-COVERED RING', 'SHORT-SLEEVED LINEN T-SHIRT', 'BASEBALL CAP', 'COTTON HALF-PLACKET LONG-SLEEVE HENLEY TOP', 'MESH BASEBALL CAP', 'ORGANIC COTTON SWEATSHIRT', 'COTTON-MIX LONG SHORTS', 'COTTON-KNIT T-SHIRT', 'BOXY T-SHIRT', 'ORGANIC COTTON-LYOCELL MIX HALF PLACKET SHIRT', 'ORGANIC COTTON CONTRAST PANEL T-SHIRT', 'LOOSE COTTON TROUSERS', 'ORGANIC COTTON CONTRAST PANEL SHIRT', 'ORGANIC COTTON DENIM CARGO SHORTS', 'KNEE-LENGTH LINEN SHORTS', 'ORGANIC COTTON CONTRAST PANEL STRIPE SHIRT', 'RELAXED ORGANIC COTTON DENIM SHORTS', 'RECYCLED POLYESTER PLISSE SHORT SLEEVE SHIRT', 'PLISSE RECYCLED POLYESTER SHIRT', 'ELASTICATED ORGANIC-COTTON TROUSERS', 'ORGANIC COTTON POPLIN SHIRT', 'WOVEN-PANELLED POLO SHIRT', 'ORGANIC COTTON TOP WITH DENIM POCKET', 'COTTON OVERSIZED GRANDAD COLLAR SHIRT', 'LONG LEATHER ZIP WALLET', 'RECYCLED TECHNICAL BELT BAG', 'REGULAR-FIT ORGANIC COTTON SHORTS', 'REGULAR-FIT ORGANI
# ...

# %%
original_price_list = list()
elem = driver.find_elements_by_class_name('is-deprecated')
for i in elem:
    original_price_list.append(i.text.replace("€",""))
print(original_price_list)
len(original_price_list)
# Out:
# ['17', '29', '29', '19', '35', '25', '29', '29', '49', '55', '55', '35', '59', '39', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '45', '45', '79', '49', '49', '49', '49', '49', '89', '89', '89', '55', '49', '55', '55', '59', '59', '59', '59', '59', '59', '59', '59', '59', '99', '115', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '69', '125', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '79', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '89', '150', '150', '99', '99', '99', '175', '175', '135', '135', '135', '175', '175', '175', '195', '275', '290']
# 119

# %%
discount_price_list = list()
elem = driver.find_elements_by_class_name('is-reduced')
for i in elem:
    discount_price_list.append(i.text.replace("€","").replace(",","."))
print(discount_price_list)
len(discount_price_list)
# Out:
# ['8.50', '8.70', '8.70', '9.50', '10.50', '12.50', '14.50', '14.50', '14.70', '16.50', '16.50', '17.50', '17.70', '19.50', '20.70', '20.70', '20.70', '20.70', '20.70', '20.70', '20.70', '20.70', '20.70', '20.70', '22.50', '22.50', '23.70', '24.50', '24.50', '24.50', '24.50', '24.50', '26.70', '26.70', '26.70', '27.50', '27.50', '27.50', '27.50', '29.50', '29.50', '29.50', '29.50', '29.50', '29.50', '29.50', '29.50', '29.50', '29.70', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '34.50', '37.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '39.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '44.50', '45', '45', '49.50', '49.50', '49.50', '52.50', '52.50', '67.50', '67.50',
# ...

# %%
imgs = driver.find_elements_by_class_name('a-image.default-image.ResolveComplete')
mi_result=[]
for img in imgs:
    mi_result.append(img.get_attribute('src'))
print(mi_result)
len(mi_result)
# Out:
# ['https://lp.cosstores.com/app001prod?set=key%5Bresolve.pixelRatio%5D,value%5B1%5D&set=key%5Bresolve.width%5D,value%5B250%5D&set=key%5Bresolve.height%5D,value%5B10000%5D&set=key%5Bresolve.imageFit%5D,value%5Bcontainerwidth%5D&set=key%5Bresolve.allowImageUpscaling%5D,value%5B0%5D&set=key%5Bresolve.format%5D,value%5Bwebp%5D&set=key%5Bresolve.quality%5D,value%5B60%5D&set=ImageVersion%5B1%5D,origin%5Bdam%5D,source%5B/e4/5f/e45f30492c0c9a73164f49d6725839ab167c5e6d.jpg%5D,type%5BDESCRIPTIVESTILLLIFE%5D&call=url%5Bfile:/product/dynamic.chain%5D', 'https://lp.cosstores.com/app001prod?set=key%5Bresolve.pixelRatio%5D,value%5B1%5D&set=key%5Bresolve.width%5D,value%5B250%5D&set=key%5Bresolve.height%5D,value%5B10000%5D&set=key%5Bresolve.imageFit%5D,value%5Bcontainerwidth%5D&set=key%5Bresolve.allowImageUpscaling%5D,value%5B0%5D&set=key%5Bresolve.format%5D,value%5Bwebp%5D&set=key%5Bresolve.quality%5D,value%5B60%5D&set=ImageVersion%5B1%5D,origin%5Bdam%5D,source%5B/4d/b9/4db95cfab8a7676c220f22416c08de
# ...

# %%
imgs = driver.find_elements_by_class_name('a-image.ResolveComplete')
result=[]
for img in imgs:
    result.append(img.get_attribute('src'))
print(result)
len(result)
# Out:
# ['https://lp.cosstores.com/app001prod?set=key%5Bresolve.pixelRatio%5D,value%5B1%5D&set=key%5Bresolve.width%5D,value%5B250%5D&set=key%5Bresolve.height%5D,value%5B10000%5D&set=key%5Bresolve.imageFit%5D,value%5Bcontainerwidth%5D&set=key%5Bresolve.allowImageUpscaling%5D,value%5B0%5D&set=key%5Bresolve.format%5D,value%5Bwebp%5D&set=key%5Bresolve.quality%5D,value%5B60%5D&set=ImageVersion%5B1%5D,origin%5Bdam%5D,source%5B/e4/5f/e45f30492c0c9a73164f49d6725839ab167c5e6d.jpg%5D,type%5BDESCRIPTIVESTILLLIFE%5D&call=url%5Bfile:/product/dynamic.chain%5D', 'https://lp.cosstores.com/app001prod?set=key%5Bresolve.pixelRatio%5D,value%5B1%5D&set=key%5Bresolve.width%5D,value%5B250%5D&set=key%5Bresolve.height%5D,value%5B10000%5D&set=key%5Bresolve.imageFit%5D,value%5Bcontainerwidth%5D&set=key%5Bresolve.allowImageUpscaling%5D,value%5B0%5D&set=key%5Bresolve.format%5D,value%5Bwebp%5D&set=key%5Bresolve.quality%5D,value%5B60%5D&set=ImageVersion%5B1%5D,origin%5Bdam%5D,source%5B/54/2c/542c503d3423d46c64aa573280b1c5
# ...

# %%
a3 = []
for i in result:
    if i not in mi_result:
        a3.append(i)
a3
len(a3)
# Out:
# 119

# %%
# !pip install pandas

# %%
#DataFrame 전부 보여주는 코드
import pandas as pd
print("pandas version: ", pd.__version__)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', -1)
# Out:
# pandas version:  1.0.1
# C:\Users\BLUE\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
df = pd.DataFrame([ x for x in zip(product_list, original_price_list, discount_price_list)])
print(df)
# Out:
#                                                      0    1       2
# 0    ROUND-NECK T-SHIRT                                 17   8.50
# 1    RECYCLED POLYESTER 3-PANEL BUCKET HAT              29   8.70
# 2    MESH BASEBALL CAP                                  29   8.70
# 3    LEATHER-COVERED RING                               19   9.50
# 4    SHORT-SLEEVED LINEN T-SHIRT                        35   10.50
# 5    BASEBALL CAP                                       25   12.50
# 6    COTTON HALF-PLACKET LONG-SLEEVE HENLEY TOP         29   14.50
# 7    MESH BASEBALL CAP                                  29   14.50
# 8    ORGANIC COTTON SWEATSHIRT                          49   14.70
# 9    COTTON-MIX LONG SHORTS                             55   16.50
# 10   COTTON-KNIT T-SHIRT                                55   16.50
# 11   BOXY T-SHIRT                                       35   17.50
# 12   ORGANIC COTTON-LYOCELL MIX HALF PLACKET SHIRT      59   17.70
# ...

# %%
df. columns = ["Product", "Original Price", "Discount Price"]
df
# Out:
#                                                Product Original Price  \
# 0    ROUND-NECK T-SHIRT                                 17
# 1    RECYCLED POLYESTER 3-PANEL BUCKET HAT              29
# 2    MESH BASEBALL CAP                                  29
# 3    LEATHER-COVERED RING                               19
# 4    SHORT-SLEEVED LINEN T-SHIRT                        35
# 5    BASEBALL CAP                                       25
# 6    COTTON HALF-PLACKET LONG-SLEEVE HENLEY TOP         29
# 7    MESH BASEBALL CAP                                  29
# 8    ORGANIC COTTON SWEATSHIRT                          49
# 9    COTTON-MIX LONG SHORTS                             55
# 10   COTTON-KNIT T-SHIRT                                55
# 11   BOXY T-SHIRT                                       35
# 12   ORGANIC COTTON-LYOCELL MIX HALF PLACKET SHIRT      59
# 13   ORGANIC COTTON CONTRAST PANEL T-SHIRT              39
# 14   LOOSE COTTON TROUSERS                              69
# ...

# %%
import numpy as np
df["Discount Rate"] = np.nan
df
# Out:
#                                                Product Original Price  \
# 0    ROUND-NECK T-SHIRT                                 17
# 1    RECYCLED POLYESTER 3-PANEL BUCKET HAT              29
# 2    MESH BASEBALL CAP                                  29
# 3    LEATHER-COVERED RING                               19
# 4    SHORT-SLEEVED LINEN T-SHIRT                        35
# 5    BASEBALL CAP                                       25
# 6    COTTON HALF-PLACKET LONG-SLEEVE HENLEY TOP         29
# 7    MESH BASEBALL CAP                                  29
# 8    ORGANIC COTTON SWEATSHIRT                          49
# 9    COTTON-MIX LONG SHORTS                             55
# 10   COTTON-KNIT T-SHIRT                                55
# 11   BOXY T-SHIRT                                       35
# 12   ORGANIC COTTON-LYOCELL MIX HALF PLACKET SHIRT      59
# 13   ORGANIC COTTON CONTRAST PANEL T-SHIRT              39
# 14   LOOSE COTTON TROUSERS                              69
# ...

# %%
df['Original Price'] = pd.to_numeric(df['Original Price'])
df['Discount Price'] = pd.to_numeric(df['Discount Price'])

# %%
df['Discount Rate'] = 1 - df['Discount Price'] / df['Original Price']

# %%
df
# Out:
#                                                Product  Original Price  \
# 0    ROUND-NECK T-SHIRT                                 17
# 1    RECYCLED POLYESTER 3-PANEL BUCKET HAT              29
# 2    MESH BASEBALL CAP                                  29
# 3    LEATHER-COVERED RING                               19
# 4    SHORT-SLEEVED LINEN T-SHIRT                        35
# 5    BASEBALL CAP                                       25
# 6    COTTON HALF-PLACKET LONG-SLEEVE HENLEY TOP         29
# 7    MESH BASEBALL CAP                                  29
# 8    ORGANIC COTTON SWEATSHIRT                          49
# 9    COTTON-MIX LONG SHORTS                             55
# 10   COTTON-KNIT T-SHIRT                                55
# 11   BOXY T-SHIRT                                       35
# 12   ORGANIC COTTON-LYOCELL MIX HALF PLACKET SHIRT      59
# 13   ORGANIC COTTON CONTRAST PANEL T-SHIRT              39
# 14   LOOSE COTTON TROUSERS                              69
# ...

# %%
df["Images"] = pd.DataFrame({"Images":a3})

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

df.style.format({'Images': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_dcde581c_64cb_11eb_b482_0cd292f6b322" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Product</th>        <th class="col_heading level0 col1" >Original Price</th>        <th class="col_heading level0 col2" >Discount Price</th>        <th class="col_heading level0 col3" >Discount Rate</th>        <th class="col_heading level0 col4" >Images</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dcde581c_64cb_11eb_b482_0cd292f6b322level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dcde581c_64cb_11eb_b482_0cd292f6b322row0_col0" class="data row0 col0" >ROUND-NECK T-SHIRT</td>
#                         <td id="T_dcde581c_64cb_11eb_b482_0cd292f6b322row0_col1" class="data row0 col1" >17</td>
#                         <td id="T_dcde581c_64cb_11eb_b482_0cd292f6b322row0_col2" class="data row0 col2" >8.500000</td>
# ...

# %%
ddf = df.sort_values(by='Discount Rate', ascending = False)

ddf.style.format({'Images': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_e1966536_64cb_11eb_a27b_0cd292f6b322" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Product</th>        <th class="col_heading level0 col1" >Original Price</th>        <th class="col_heading level0 col2" >Discount Price</th>        <th class="col_heading level0 col3" >Discount Rate</th>        <th class="col_heading level0 col4" >Images</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1966536_64cb_11eb_a27b_0cd292f6b322level0_row0" class="row_heading level0 row0" >104</th>
#                         <td id="T_e1966536_64cb_11eb_a27b_0cd292f6b322row0_col0" class="data row0 col0" >COTTON TRENCH COAT</td>
#                         <td id="T_e1966536_64cb_11eb_a27b_0cd292f6b322row0_col1" class="data row0 col1" >150</td>
#                         <td id="T_e1966536_64cb_11eb_a27b_0cd292f6b322row0_col2" class="data row0 col2" >45.000000</td>
# ...

# %%
#이미지 링크 없는 완성본
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup
import time

path = 'C:\\Users\\BLUE\\Desktop\\Selenium\\chromedriver'
driver = webdriver.Chrome(path)

driver.get('https://www.cosstores.com/en_de/men/archive-sale.html')
time.sleep(2)

elem = driver.find_element_by_css_selector('#main-content > div > div.genericpagepar.parsys > div.productlisting.parbase.section > div.u-cols-lg-24-24.u-cols-md-12-12.u-cols-sm-12-12.u-row.u-full-width > div > div > div.o-product-sort > div > div > div > div > div > button.a-button-nostyle.placeholder > span:nth-child(1)')
elem.click()
time.sleep(1)

elem = driver.find_element_by_css_selector('#brand3 > span')
elem.click()
time.sleep(1)

SCROLL_PAUSE_SEC = 1

# 스크롤 높이 가져옴
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # 끝까지 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 1초 대기
    time.sleep(SCROLL_PAUSE_SEC)

    # 스크롤 다운 후 스크롤 높이 다시 가져옴
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height
    

product_list = list()
elem = driver.find_elements_by_class_name('product-title')
for i in elem:
    product_list.append(i.text)

original_price_list = list()
elem = driver.find_elements_by_class_name('is-deprecated')
for i in elem:
    original_price_list.append(i.text.replace("€",""))

discount_price_list = list()
elem = driver.find_elements_by_class_name('is-reduced')
for i in elem:
    discount_price_list.append(i.text.replace("€","").replace(",","."))

# !pip install pandas
import pandas as pd
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

df = pd.DataFrame([ x for x in zip(product_list, original_price_list, discount_price_list)])

df. columns = ["Product", "Original Price", "Discount Price"]
import numpy as np
df["Discount Rate"] = np.nan
df['Original Price'] = pd.to_numeric(df['Original Price'])
df['Discount Price'] = pd.to_numeric(df['Discount Price'])
df['Discount Rate'] = 1 - df['Discount Price'] / df['Original Price']
df
# Out:
# ...
#                                            Product  Original Price  \
# 0            RECYCLED POLYESTER 3-PANEL BUCKET HAT              29
# 1                                MESH BASEBALL CAP              29
# 2                        SLEEVELESS COTTON T-SHIRT              29
# 3                      SHORT-SLEEVED LINEN T-SHIRT              35
# 4                         LEATHER-COVERED BRACELET              25
# 5                                     BASEBALL CAP              25
# 6                               SPORTY SWIM SHORTS              45
# 7                               LEATHER CARDHOLDER              29
# 8       COTTON HALF-PLACKET LONG-SLEEVE HENLEY TOP              29
# 9                                MESH BASEBALL CAP              29
# 10                          COTTON-MIX LONG SHORTS              55
# 11                             COTTON-KNIT T-SHIRT              55
# 12                CRINKLED ORGANIC COTTON TROUSERS              79
# ...

# %%
#완성본
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from selenium.webdriver.common.keys import Keys

path = 'C:\\Users\\BLUE\\Desktop\\DataScience\\Selenium\\chromedriver'
driver = webdriver.Chrome(path)

driver.get('https://www.cosstores.com/en_de/men/archive-sale.html')
time.sleep(2)

elem = driver.find_element_by_css_selector('#oPage > main > div > div.genericpagepar.parsys > div.productlisting.parbase.section > div.u-cols-lg-24-24.u-cols-md-12-12.u-cols-sm-12-12.u-row.u-full-width > div > div > div.o-product-sort > div > div > div > div > div > button.a-button-nostyle.placeholder > span:nth-child(1)')
elem.click()


time.sleep(1)

elem = driver.find_element_by_css_selector('#brand3 > span')
elem.click()
time.sleep(1)

#하나하나 스크롤 내리는 코드
data = [i for i in range(1,50000) if i %500 ==0]
import datetime
def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    for x in data:
        driver.execute_script("window.scrollTo(0, {})".format((x)))
        time.sleep(2)
        if datetime.datetime.now() > end:
            break
            
doScrollDown(100)

product_list = list()
elem = driver.find_elements_by_class_name('product-title')
for i in elem:
    product_list.append(i.text)

original_price_list = list()
elem = driver.find_elements_by_class_name('is-deprecated')
for i in elem:
    original_price_list.append(i.text.replace("€",""))

discount_price_list = list()
elem = driver.find_elements_by_class_name('is-reduced')
for i in elem:
    discount_price_list.append(i.text.replace("€","").replace(",","."))

imgs = driver.find_elements_by_class_name('a-image.default-image.ResolveComplete')
mi_result=[]
for img in imgs:
    mi_result.append(img.get_attribute('src'))

imgs = driver.find_elements_by_class_name('a-image.ResolveComplete')
result=[]
for img in imgs:
    result.append(img.get_attribute('src'))

a3 = []
for i in result:
    if i not in mi_result:
        a3.append(i)

import pandas as pd
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', -1)

df = pd.DataFrame([ x for x in zip(product_list, original_price_list, discount_price_list)])

df. columns = ["Product", "Original Price", "Discount Price"]

import numpy as np
df["Discount Rate"] = np.nan

df['Original Price'] = pd.to_numeric(df['Original Price'])
df['Discount Price'] = pd.to_numeric(df['Discount Price'])

df['Discount Rate'] = 1 - df['Discount Price'] / df['Original Price']

df["Images"] = pd.DataFrame({"Images":a3})

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

df.style.format({'Images': make_clickable})

ddf = df.sort_values(by='Discount Rate', ascending = False)

ddf.style.format({'Images': make_clickable})
# Out:
# C:\Users\BLUE\anaconda3\lib\site-packages\ipykernel_launcher.py:71: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# <style  type="text/css" >
# </style><table id="T_682d5368_70f7_11eb_b491_0cd292f6b322" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Product</th>        <th class="col_heading level0 col1" >Original Price</th>        <th class="col_heading level0 col2" >Discount Price</th>        <th class="col_heading level0 col3" >Discount Rate</th>        <th class="col_heading level0 col4" >Images</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_682d5368_70f7_11eb_b491_0cd292f6b322level0_row0" class="row_heading level0 row0" >49</th>
# ...

# %%
#완성본 코드 간략히
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from selenium.webdriver.common.keys import Keys

path = 'C:\\Users\\BLUE\\Desktop\\DataScience\\Selenium\\chromedriver'
driver = webdriver.Chrome(path)

driver.get('https://www.cosstores.com/en_de/men/archive-sale.html?sort=ascPrice')
time.sleep(2)

#하나하나 스크롤 내리는 코드
data = [i for i in range(1,50000) if i %500 ==0]
import datetime
def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    for x in data:
        driver.execute_script("window.scrollTo(0, {})".format((x)))
        time.sleep(2)
        if datetime.datetime.now() > end:
            break
            
doScrollDown(100)

product_list = list()
elem = driver.find_elements_by_class_name('product-title')
for i in elem:
    product_list.append(i.text)

original_price_list = list()
elem = driver.find_elements_by_class_name('is-deprecated')
for i in elem:
    original_price_list.append(i.text.replace("€",""))

discount_price_list = list()
elem = driver.find_elements_by_class_name('is-reduced')
for i in elem:
    discount_price_list.append(i.text.replace("€","").replace(",","."))

imgs = driver.find_elements_by_class_name('a-image.default-image.ResolveComplete')
mi_result=[]
for img in imgs:
    mi_result.append(img.get_attribute('src'))

imgs = driver.find_elements_by_class_name('a-image.ResolveComplete')
result=[]
for img in imgs:
    result.append(img.get_attribute('src'))

a3 = []
for i in result:
    if i not in mi_result:
        a3.append(i)

print('Number of items:',len(product_list))
        
import pandas as pd
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', -1)

df = pd.DataFrame([ x for x in zip(product_list, original_price_list, discount_price_list)])

df. columns = ["Product", "Original Price", "Discount Price"]

import numpy as np
df["Discount Rate"] = np.nan

df['Original Price'] = pd.to_numeric(df['Original Price'])
df['Discount Price'] = pd.to_numeric(df['Discount Price'])

df['Discount Rate'] = 1 - df['Discount Price'] / df['Original Price']

df["Images"] = pd.DataFrame({"Images":a3})

def make_clickable(val):
    # target _blank to open new window
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)

df.style.format({'Images': make_clickable})

ddf = df.sort_values(by='Discount Rate', ascending = False)

ddf.style.format({'Images': make_clickable})
